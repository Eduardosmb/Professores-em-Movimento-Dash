# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/idh_por_bairro.csv', sep=',')
df10 = df.head(10)
df10.head()
# Out:
#             DISTRITO      IDHM
# 0  Alto de Pinheiros  0.917500
# 1         Anhanguera  0.660333
# 2         Aricanduva  0.731115
# 3        Artur Alvim  0.713708
# 4        Barra Funda  0.799667

# %%
df10 = df10.sort_values(by='IDHM', ascending=False).round(2)
df10.head()
# Out:
#             DISTRITO  IDHM
# 0  Alto de Pinheiros  0.92
# 4        Barra Funda  0.80
# 9               Brás  0.79
# 5         Bela Vista  0.79
# 6              Belém  0.79

# %%
plt.figure(figsize=(10,5))
plt.bar(df10['DISTRITO'], df10['IDHM'])
plt.title('DISTRITO X IDHM')
plt.xlabel('DISTRITO')
plt.xticks(rotation=90)
plt.ylabel('IDHM')

for i in range(len(df10)):
    plt.annotate(df10['IDHM'].iloc[i], xy=(i-0.2, df10['IDHM'].iloc[i]+0.01))
plt.show()
